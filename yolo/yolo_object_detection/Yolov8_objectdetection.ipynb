# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip /content/drive/MyDrive/opencv-bad.v1i.yolov8.zip -d yolo
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: yolo/train/labels/12_08_2024_14_48_13-657210_classifier_input_png.rf.28ed32107a5613488e52f15a68650827.txt
#   inflating: yolo/train/labels/12_08_2024_15_09_56-000072_classifier_input_png.rf.05a45821c57ca5bb8e80ac55044427cf.txt
#   inflating: yolo/train/labels/12_08_2024_15_09_56-955403_classifier_input_png.rf.c807374afcc548229a47c533fe8cfad1.txt
#   inflating: yolo/train/labels/12_08_2024_15_09_57-280369_classifier_input_png.rf.9f49c101a5dbaf44d1f414305c5e6728.txt
#   inflating: yolo/train/labels/12_08_2024_15_10_50-996599_classifier_input_png.rf.eced7e21a42087ec7d34c2b3783ac4b4.txt
#   inflating: yolo/train/labels/12_08_2024_16_09_48-271876_classifier_input_png.rf.eee415deba96b70cd5c883e59f77126c.txt
#   inflating: yolo/train/labels/12_08_2024_16_09_48-874458_classifier_input_png.rf.9231e8b98a9744e2ac2e62330f2ec51b.txt
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.8/898.8 kB 48.4 MB/s eta 0:00:00
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.48 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.9/112.6 GB disk)

# %%
from ultralytics import YOLO

# %%
model=YOLO('yolov8n.pt')
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 21.7MB/s]

# %%
model.train(data="/content/yolo/data.yaml",epochs=20)
# Out:
# Ultralytics 8.3.48 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model=YOLO("/home/hari07/workspace/intern/yolo/yolo_object_detection/runs/detect/train/weights/best.pt")

# %%
model.predict(source="/home/hari07/workspace/intern/anomaly_detection_test_data/anomaly_detection_test_data/bad/03_08_2024_16_54_38.244099_classifier_input.png",save=True)
# Out:
# image 1/1 /home/hari07/workspace/intern/anomaly_detection_test_data/anomaly_detection_test_data/bad/03_08_2024_16_54_38.244099_classifier_input.png: 288x640 1 bad, 108.3ms
# Speed: 2.6ms preprocess, 108.3ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 640)
# Results saved to runs/detect/predict4
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'bad', 1: 'good'}
#  obb: None
#  orig_img: array([[[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
# ...
